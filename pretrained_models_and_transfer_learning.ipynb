# %%
from IPython.display import HTML

video_url = "https://3b1b-posts.us-east-1.linodeobjects.com/content/lessons/2017/neural-networks/pixels-to-neurons.mp4"

HTML(f"""
    <video width="600" controls>
        <source src="{video_url}" type="video/mp4">
        Your browser does not support the video tag.
    </video>
""")
# Out:
#     <video width="600" controls>
#         <source src="https://3b1b-posts.us-east-1.linodeobjects.com/content/lessons/2017/neural-networks/pixels-to-neurons.mp4" type="video/mp4">
#         Your browser does not support the video tag.
#     </video>

# %%
from IPython.display import HTML

video_url = "https://3b1b-posts.us-east-1.linodeobjects.com/content/lessons/2017/neural-networks/network-propagation.mp4#t=0.001"

HTML(f"""
    <video width="600" controls>
        <source src="{video_url}" type="video/mp4">
        Your browser does not support the video tag.
    </video>
""")
# Out:
#     <video width="600" controls>
#         <source src="https://3b1b-posts.us-east-1.linodeobjects.com/content/lessons/2017/neural-networks/network-propagation.mp4#t=0.001" type="video/mp4">
#         Your browser does not support the video tag.
#     </video>

# %% [markdown]
# ## 1. ImageNet: A Pioneering Vision for Computers
# It all began in 1985. George A. Miller and his team at Princeton University started working on WordNet, a lexical database for the English language. As a cross between a dictionary and a thesaurus, it enabled applications in Natural Language Processing (NLP).
#
# Fast forward 21 years and data scientist Fei-Fei Li came up with the idea of ImageNet at the University of Illinois Urbana-Champaign. At the time, most AI researchers thought algorithms were more important than the data itself. However, Li was convinced that vast amounts of real-world data would make algorithms more accurate. By then, WordNet was mature, and the version 3.0 had recently been released. When Li met WordNet researcher Christiane Fellbaum from Princeton University, she decided to use the wordbase and hierarchy of WordNet for her ambitious image database. Her aim? Support visual object recognition software research.
#
# #### Collective Contributions With Spectacular Results
#
# In July 2008, ImageNet had zero images. By December, it had categorized three million images across 6,000+ synsets. In April 2010, there were more than 11 million images in 15,000+ synsets. Such results would have been inconceivable for a handful of researchers. They were made possible through crowdsourcing on Amazon’s Mechanical Turk platform.
#
# In 2010, the first ever ImageNet Large Scale Visual Recognition Challenge (ILSVRC) was organized. Software programs competed to correctly classify and detect objects and scenes.
#
# Since being launched, ImageNet has given researchers a common set of images to benchmark their models and algorithms. In turn, this has driven research in machine learning and deep neural networks, making it easier to classify images and complete other tasks associated with computer vision. The data is available for free to researchers for non-commercial use.

# %% [markdown]
# <div class="alert alert-block alert-success"> <h4>📌 Key Dates </h4>
# <div>
# <h3> 2009 </h3>
#
# **ImageNet**
#
# ImageNet is presented for the first time as a poster at the Conference on Computer Vision and Pattern Recognition (CVPR) in Florida.
#
# <h3>2012</h3>
#
# **AlexNet**
# The deep convolutional neural network architecture AlexNet beats the field in the ImageNet Challenge by a whopping 10.8% — arguably kickstarting the current boom in computer vision.
#
# <h3>2017</h3>
#
# **95% Accuracy in Computer Vision**
# 29 of 38 the teams competing in the ImageNet Challenge achieve greater than 95% accuracy. Image recognition has been taken to unprecedented levels.

# %% [markdown]
# <!DOCTYPE html>
# <html lang="en">
# <head>
#   <meta charset="UTF-8">
#   <meta name="viewport" content="width=device-width, initial-scale=1.0">
#   <title>Pretrained Models</title>
#   <style>
#     body {
#       font-family: Arial, sans-serif;
#       background-color: #f9f9f9;
#     }
#     .table-container {
#       max-width: 900px;
#       margin: auto;
#       padding: 20px;
#       background-color: white;
#       border-radius: 10px;
#       color: rgb(22, 6, 80);
#       box-shadow: 0 0 10px rgba(0, 0, 0, 0.1);
#     }
#     table {
#       width: 100%;
#       border-collapse: collapse;
#     }
#     th, td {
#       padding: 12px;
#       text-align: left;
#       border-bottom: 1px solid #ddd;
#     }
#     th {
#       background-color:rgb(157, 195, 238);
#       color: white;
#     }
#     tr:nth-child(even) {
#       background-color: #f2f2f2;
#     }
#     tr:hover {
#       background-color: #ddd;
#     }
#   </style>
# </head>
# <body>
#
# <div class="table-container">
# <h3>ImageNet Competition Winners</h3>
#   <table>
#     <thead>
#       <tr>
#         <th>Year</th>
#         <th>Winning Model/Team</th>
#         <th>Top-5 Error Rate (%)</th>
#       </tr>
#     </thead>
#     <tbody>
#       <tr>
#         <td>2010</td>
#         <td>NEC Labs America & UIUC (SVM)</td>
#         <td>28.2</td>
#       </tr>
#       <tr>
#         <td>2011</td>
#         <td>XRCE (SVM with Fisher Vectors)</td>
#         <td>25.0</td>
#       </tr>
#       <tr>
#         <td>2012</td>
#         <td>AlexNet (University of Toronto)</td>
#         <td>16.4</td>
#       </tr>
#       <tr>
#         <td>2013</td>
#         <td>ZFNet</td>
#         <td>~11.2</td>
#       </tr>
#       <tr>
#         <td>2014</td>
#         <td>GoogLeNet (Inception v1)</td>
#         <td>~6.7</td>
#       </tr>
#       <tr>
#         <td>2015</td>
#         <td>ResNet (Microsoft Research)</td>
#         <td>3.57</td>
#       </tr>
#       <tr>
#         <td>2016</td>
#         <td>SENet</td>
#         <td>3.0</td>
#       </tr>
#       <tr>
#         <td>2017</td>
#         <td>Dual-Path Networks (DPNs)</td>
#         <td>~2.99</td>
#       </tr>
#       <tr>
#         <td>2018</td>
#         <td>NASNet-A</td>
#         <td>~2.9</td>
#       </tr>
#       <tr>
#         <td>2019</td>
#         <td>EfficientNet</td>
#         <td>~2.7</td>
#       </tr>
#       <tr>
#         <td>2020</td>
#         <td>Vision Transformer (ViT)</td>
#         <td>~2.5</td>
#       </tr>
#       <tr>
#         <td>2021</td>
#         <td>Swin Transformer</td>
#         <td>~2.4</td>
#       </tr>
#       <tr>
#         <td>2022</td>
#         <td>ConvNeXt</td>
#         <td>~2.3</td>
#       </tr>
#       <tr>
#         <td>2023</td>
#         <td>CoAtNet</td>
#         <td>~2.2</td>
#       </tr>
#       <tr>
#         <td>2024</td>
#         <td>InternImage</td>
#         <td>~2.1</td>
#       </tr>
#     </tbody>
#   </table>
# </div>
#
# </body>
# </html>

# %% [markdown]
# ## 2. Pretrained models
#
# Using pretrained models in deep learning offers several advantages over creating models from scratch, as highlighted below:
#
# ### **Advantages of Pretrained Models**
#
# 1. **Reduced Training Time**:
#     - Pretrained models are already trained on large datasets, so they have learned meaningful features. Fine-tuning them for a specific task requires significantly less time compared to training from scratch.
#     - For example, training a model from scratch can take months, while fine-tuning a pretrained model can be accomplished in weeks or even days.
# 2. **Lower Computational Costs**:
#     - Training deep learning models from scratch requires massive computational resources and expensive hardware. Pretrained models reduce these requirements by leveraging precomputed weights and features.
# 3. **Better Performance with Limited Data**:
#     - Pretrained models are particularly useful when labeled data is scarce. They transfer knowledge from large datasets to smaller, domain-specific datasets, improving performance even with limited training data.
# 4. **Improved Accuracy**:
#     - Pretrained models often achieve state-of-the-art performance because they start with weights optimized on large, diverse datasets like ImageNet. This provides a strong foundation for fine-tuning on specialized tasks.
# 5. **Ease of Use**:
#     - Developers can use pretrained models as-is or adapt them for specific use cases through transfer learning. This simplifies the development process and makes machine learning more accessible to non-experts.
# 6. **Knowledge Transfer**:
#     - Pretrained models act as a form of transfer learning, where knowledge gained from one domain (source) is applied to another domain (target). This is especially effective in tasks like natural language processing, computer vision, and speech recognition.
# 7. **Cost Efficiency**:
#     - By reducing the need for extensive data collection, annotation, and computational resources, pretrained models save significant costs in AI development.
# ### **Applications of Pretrained Models**
#
# - **Natural Language Processing (NLP)**: Used in translation, chatbots, and large language models like GPT.
# - **Computer Vision**: Applied in object detection, image segmentation, and classification.
# - **Healthcare**: Accelerates drug discovery and medical image analysis.
# - **Cybersecurity**: Detects anomalies and phishing attacks.
# - **Creative Workflows**: Powers AI art tools and generative design systems.
#
#
# ### **Challenges of Training From Scratch**
#
# - Requires vast amounts of labeled data.
# - Demands high computational power.
# - Involves complex optimization processes that are time-consuming and prone to overfitting when data is limited.

# %% [markdown]
# <!DOCTYPE html>
# <html lang="en">
# <head>
#   <meta charset="UTF-8">
#   <meta name="viewport" content="width=device-width, initial-scale=1.0">
#   <title>Pretrained Models</title>
#   <style>
#     body {
#       font-family: Arial, sans-serif;
#       background-color: #f9f9f9;
#     }
#     .table-container {
#       max-width: 950px;
#       margin: auto;
#       padding: 20px;
#       background-color: white;
#       border-radius: 10px;
#       color: rgb(73, 6, 6);
#       box-shadow: 0 0 10px rgba(0, 0, 0, 0.1);
#     }
#     table {
#       width: 100%;
#       border-collapse: collapse;
#     }
#     th, td {
#       padding: 12px;
#       text-align: left;
#       border-bottom: 1px solid #ddd;
#     }
#     th {
#       background-color:rgb(231, 25, 25);
#       color: white;
#     }
#     tr:nth-child(even) {
#       background-color: #f2f2f2;
#     }
#     tr:hover {
#       background-color: #ddd;
#     }
#     .scrollable-body {
#       max-height: 300px; /* Set the height of the scrollable area */
#       overflow-y: auto; /* Enables vertical scrolling */
#     }
#   </style>
# </head>
# <body>
#
# <div class="table-container">
#   <h3>Examples of Pretrained Models</h3>
#   <table>
#     <thead>
#       <tr>
#         <th>#</th>
#         <th>Model Name</th>
#         <th>Model Type</th>
#         <th>Training Data</th>
#         <th>Data Size</th>
#         <th>Application Area</th>
#         <th>Common Uses</th>
#       </tr>
#     </thead>
#     <div class="scrollable-body">
#       <tbody>
#         <tr>
#           <td>1</td>
#           <td>AlexNet</td>
#           <td>Convolutional Neural Network (CNN)</td>
#           <td>ImageNet</td>
#           <td>1.2M images</td>
#           <td>Computer Vision</td>
#           <td>Image Classification</td>
#         </tr>
#         <tr>
#           <td>2</td>
#           <td>ResNet</td>
#           <td>Residual CNN</td>
#           <td>ImageNet</td>
#           <td>1.2M images</td>
#           <td>Computer Vision</td>
#           <td>Image Classification</td>
#         </tr>
#         <tr>
#           <td>3</td>
#           <td>GoogLeNet</td>
#           <td>Inception CNN</td>
#           <td>ImageNet</td>
#           <td>1.2M images</td>
#           <td>Computer Vision</td>
#           <td>Image Classification</td>
#         </tr>
#         <tr>
#           <td>4</td>
#           <td>BERT</td>
#           <td>Transformer</td>
#           <td>BooksCorpus & Wikipedia</td>
#           <td>800M words</td>
#           <td>Natural Language Processing (NLP)</td>
#           <td>Text Classification, Question Answering</td>
#         </tr>
#         <tr>
#           <td>5</td>
#           <td>NVIDIA NeMo Megatron</td>
#           <td>Transformer</td>
#           <td>Custom Large Text Corpus</td>
#           <td>45B parameters</td>
#           <td>NLP</td>
#           <td>Translation, Chatbots</td>
#         </tr>
#         <tr>
#           <td>6</td>
#           <td>MegaMolBART</td>
#           <td>Transformer</td>
#           <td>Chemistry Datasets (Molecular Structures)</td>
#           <td>1.5M molecules</td>
#           <td>Healthcare & Drug Discovery</td>
#           <td>Molecular Property Prediction, Drug Discovery</td>
#         </tr>
#         <tr>
#           <td>7</td>
#           <td>SqueezeNet</td>
#           <td>Lightweight CNN</td>
#           <td>ImageNet</td>
#           <td>1.2M images</td>
#           <td>Computer Vision</td>
#           <td>Low-Memory Image Classification for Edge Devices</td>
#         </tr>
#         <tr>
#           <td>8</td>
#           <td>YOLO (You Only Look Once)</td>
#           <td>Real-time CNN</td>
#           <td>COCO Dataset (Common Objects in Context)</td>
#           <td>330k images</td>
#           <td>Computer Vision</td>
#           <td>Object Detection in Images and Videos</td>
#         </tr>
#         <tr>
#           <td>9</td>
#           <td>TabPFN</td>
#           <td>Transformer</td>
#           <td>Synthetic Tabular Data</td>
#           <td>Varies (small datasets)</td>
#           <td>Tabular Data Analysis</td>
#           <td>Small Dataset Predictions for Tabular Data</td>
#         </tr>
#         <tr>
#           <td>10</td>
#           <td>NVIDIA GauGAN</td>
#           <td>Generative Adversarial Network (GAN)</td>
#           <td>NVIDIA Custom Art Dataset</td>
#           <td>1k+ images</td>
#           <td>Creative Workflows & Art Generation</td>
#           <td>AI-Assisted Art Creation and Design Tools</td>
#         </tr>
#         <tr>
#           <td>11</td>
#           <td>LLaMA (Meta)</td>
#           <td>Transformer</td>
#           <td>Custom Large Text Corpus</td>
#           <td>Varies (e.g., 7B, 13B parameters)</td>
#           <td>NLP</td>
#           <td>Text generation, conversational AI</td>
#         </tr>
#         <tr>
#           <td>12</td>
#           <td>Mistral (7B)</td>
#           <td>Transformer</td>
#           <td>Custom Text Corpus</td>
#           <td>Varies (small to large datasets)</td>
#           <td>NLP</td>
#           <td>Lightweight language modeling</td>
#         </tr>
#         <tr>
#           <td>13</td>
#           <td>BLOOM</td>
#           <td>Transformer</td>
#           <td>Multilingual Text Corpus</td>
#           <td>176B parameters</td>
#           <td>NLP (Multilingual)</td>
#           <td>Text generation, translation</td>
#         </tr>
#         <tr>
#           <td>14</td>
#           <td>BioBERT</td>
#           <td>Transformer</td>
#           <td>Biomedical Text Datasets</td>
#           <td>Varies (biomedical texts)</td>
#           <td>Biomedical NLP</td>
#           <td>Chemical/protein entity recognition, clinical research</td>
#         </tr>
#         <tr>
#           <td>15</td>
#           <td>Spleen Segmentation Model</td>
#           <td>CNN</td>
#           <td>CT Imaging Dataset</td>
#           <td>Varies (medical images)</td>
#           <td>Medical Imaging</td>
#           <td>Spleen segmentation for healthcare applications</td>
#         </tr>
#         <tr>
#           <td>16</td>
#           <td>DALL-E Mini (Craiyon)</td>
#           <td>DNN + Diffusion Model</td>
#           <td>Custom Image Dataset</td>
#           <td>Varies (image-text pairs)</td>
#           <td>Generative AI (Vision)</td>
#           <td>AI-generated images from text prompts</td>
#         </tr>
#         <tr>
#           <td>17</td>
#           <td>ELECTRA</td>
#           <td>Transformer (Efficient)</td>
#           <td>Large-scale Text Corpus</td>
#           <td>Varies (text datasets)</td>
#           <td>NLP</td>
#           <td>Text classification, chatbots, virtual assistants</td>
#         </tr>
#       </tbody>
#     </div>
#   </table>
#
#   <!-- Footer -->
#   <p style="text-align:center; font-size:12px; color:#666;">Data sourced from research papers and AI model documentation.</p>
#
# </div>
#
# </body>
# </html>

# %% [markdown]
# ## 3. Keras Applications
# Keras Applications are deep learning models that are made available alongside pre-trained weights. These models can be used for prediction, feature extraction, and fine-tuning.
#
# Weights are downloaded automatically when instantiating a model. They are stored at `~/.keras/models/`.

# %% [markdown]
# <!DOCTYPE html>
# <html lang="en">
# <head>
#   <meta charset="UTF-8">
#   <meta name="viewport" content="width=device-width, initial-scale=1.0">
#   <title>Pretrained Models</title>
#   <style>
#     body {
#       font-family: Arial, sans-serif;
#       background-color: #f9f9f9;
#     }
#     .table-container {
#       max-width: 1400px;
#       margin: auto;
#       padding: 20px;
#       background-color: white;
#       border-radius: 10px;
#       color: rgb(28, 75, 48);
#       box-shadow: 0 0 10px rgba(0, 0, 0, 0.1);
#     }
#     table {
#       width: 100%;
#       border-collapse: collapse;
#     }
#     th, td {
#       padding: 12px;
#       text-align: left;
#       border-bottom: 1px solid #ddd;
#     }
#     th {
#       background-color:rgb(16, 194, 96);
#       color: white;
#     }
#     tr:nth-child(even) {
#       background-color: #f2f2f2;
#     }
#     tr:hover {
#       background-color: #ddd;
#     }
#     .scrollable-body {
#       max-height: 500px; /* Set the height of the scrollable area */
#       overflow-y: auto; /* Enables vertical scrolling */
#     }
#   </style>
# </head>
# <body>
#
# <div class="table-container">
#   <h3>Keras in-built Pretrained Models</h3>
#   <table>
#     <thead>
#       <tr>
#         <th>#</th>
#         <th>Model Name</th>
#         <th>Model Type</th>
#         <th>Training Data</th>
#         <th>Size (MB)</th>
#         <th>Top-1 Accuracy</th>
#         <th>Top-5 Accuracy</th>
#         <th>Parameters</th>
#         <th>Depth</th>
#         <th>Application Area</th>
#         <th>Time (ms) per Inference (CPU)</th>
#         <th>Time (ms) per Inference (GPU)</th>
#       </tr>
#     </thead>
#     <tbody class="scrollable-body">
#       <tr>
#         <td>1</td>
#         <td><a href="https://keras.io/api/applications/xception">Xception</a></td>
#         <td>Convolutional Neural Network (CNN)</td>
#         <td>ImageNet</td>
#         <td>88</td>
#         <td>79.0%</td>
#         <td>94.5%</td>
#         <td>22.9M</td>
#         <td>81</td>
#         <td>Computer Vision</td>
#         <td>109.4</td>
#         <td>8.1</td>
#       </tr>
#       <tr>
#         <td>2</td>
#         <td><a href="https://keras.io/api/applications/vgg/#vgg16-function">VGG16</a></td>
#         <td>Convolutional Neural Network (CNN)</td>
#         <td>ImageNet</td>
#         <td>528</td>
#         <td>71.3%</td>
#         <td>90.1%</td>
#         <td>138.4M</td>
#         <td>16</td>
#         <td>Computer Vision</td>
#         <td>69.5</td>
#         <td>4.2</td>
#       </tr>
#       <tr>
#         <td>3</td>
#         <td><a href="https://keras.io/api/applications/vgg/#vgg19-function">VGG19</a></td>
#         <td>Convolutional Neural Network (CNN)</td>
#         <td>ImageNet</td>
#         <td>549</td>
#         <td>71.3%</td>
#         <td>90.0%</td>
#         <td>143.7M</td>
#         <td>19</td>
#         <td>Computer Vision</td>
#         <td>84.8</td>
#         <td>4.4</td>
#       </tr>
#       <tr>
#         <td>4</td>
#         <td><a href="https://keras.io/api/applications/resnet/#resnet50-function">ResNet50</a></td>
#         <td>Residual CNN</td>
#         <td>ImageNet</td>
#         <td>98</td>
#         <td>74.9%</td>
#         <td>92.1%</td>
#         <td>25.6M</td>
#         <td>107</td>
#         <td>Computer Vision</td>
#         <td>58.2</td>
#         <td>4.6</td>
#       </tr>
#       <tr>
#         <td>5</td>
#         <td><a href="https://keras.io/api/applications/resnet/#resnet50v2-function">ResNet50V2</a></td>
#         <td>Residual CNN</td>
#         <td>ImageNet</td>
#         <td>98</td>
#         <td>76.0%</td>
#         <td>93.0%</td>
#         <td>25.6M</td>
#         <td>103</td>
#         <td>Computer Vision</td>
#         <td>45.6</td>
#         <td>4.4</td>
#       </tr>
#       <tr>
#         <td>6</td>
#         <td><a href="https://keras.io/api/applications/resnet/#resnet101-function">ResNet101</a></td>
#         <td>Residual CNN</td>
#         <td>ImageNet</td>
#         <td>171</td>
#         <td>76.4%</td>
#         <td>92.8%</td>
#         <td>44.7M</td>
#         <td>209</td>
#         <td>Computer Vision</td>
#         <td>89.6</td>
#         <td>5.2</td>
#       </tr>
#       <tr>
#         <td>7</td>
#         <td><a href="https://keras.io/api/applications/resnet/#resnet101v2-function">ResNet101V2</a></td>
#         <td>Residual CNN</td>
#         <td>ImageNet</td>
#         <td>171</td>
#         <td>77.2%</td>
#         <td>93.8%</td>
#         <td>44.7M</td>
#         <td>205</td>
#         <td>Computer Vision</td>
#         <td>72.7</td>
#         <td>5.4</td>
#       </tr>
#       <tr>
#         <td>8</td>
#         <td><a href="https://keras.io/api/applications/resnet/#resnet152-function">ResNet152</a></td>
#         <td>Residual CNN</td>
#         <td>ImageNet</td>
#         <td>232</td>
#         <td>76.6%</td>
#         <td>93.1%</td>
#         <td>60.4M</td>
#         <td>311</td>
#         <td>Computer Vision</td>
#         <td>127.4</td>
#         <td>6.5</td>
#       </tr>
#       <tr>
#         <td>9</td>
#         <td><a href="https://keras.io/api/applications/resnet/#resnet152v2-function">ResNet152V2</a></td>
#         <td>Residual CNN</td>
#         <td>ImageNet</td>
#         <td>232</td>
#         <td>78.0%</td>
#         <td>94.2%</td>
#         <td>60.4M</td>
#         <td>307</td>
#         <td>Computer Vision</td>
#         <td>107.5</td>
#         <td>6.6</td>
#       </tr>
#       <tr>
#         <td>10</td>
#         <td><a href="https://keras.io/api/applications/inceptionv3">InceptionV3</a></td>
#         <td>Inception CNN</td>
#         <td>ImageNet</td>
#         <td>92</td>
#         <td>77.9%</td>
#         <td>93.7%</td>
#         <td>23.9M</td>
#         <td>189</td>
#         <td>Computer Vision</td>
#         <td>42.2</td>
#         <td>6.9</td>
#       </tr>
#       <tr>
#         <td>11</td>
#         <td><a href="https://keras.io/api/applications/inceptionresnetv2">InceptionResNetV2</a></td>
#         <td>Inception-ResNet CNN</td>
#         <td>ImageNet</td>
#         <td>215</td>
#         <td>80.3%</td>
#         <td>95.3%</td>
#         <td>55.9M</td>
#         <td>449</td>
#         <td>Computer Vision</td>
#         <td>130.2</td>
#         <td>10.0</td>
#       </tr>
#       <tr>
#         <td>12</td>
#         <td><a href="https://keras.io/api/applications/mobilenet">MobileNet</a></td>
#         <td>Lightweight CNN</td>
#         <td>ImageNet</td>
#         <td>16</td>
#         <td>70.4%</td>
#         <td>89.5%</td>
#         <td>4.3M</td>
#         <td>55</td>
#         <td>Computer Vision (Edge Devices)</td>
#         <td>22.6</td>
#         <td>3.4</td>
#       </tr>
#       <tr>
#         <td>13</td>
#         <td><a href="https://keras.io/api/applications/mobilenet/#mobilenetv2-function">MobileNetV2</a></td>
#         <td>Lightweight CNN</td>
#         <td>ImageNet</td>
#         <td>14</td>
#         <td>71.3%</td>
#         <td>90.1%</td>
#         <td>3.5M</td>
#         <td>105</td>
#         <td>Computer Vision (Edge Devices)</td>
#         <td>25.9</td>
#         <td>3.8</td>
#       </tr>
#       <tr>
#         <td>14</td>
#         <td><a href="https://keras.io/api/applications/densenet/#densenet121-function">DenseNet121</a></td>
#         <td>Dense CNN</td>
#         <td>ImageNet</td>
#         <td>33</td>
#         <td>75.0%</td>
#         <td>92.3%</td>
#         <td>8.1M</td>
#         <td>242</td>
#         <td>Computer Vision</td>
#         <td>77.1</td>
#         <td>5.4</td>
#       </tr>
#       <tr>
#         <td>15</td>
#         <td><a href="https://keras.io/api/applications/densenet/#densenet169-function">DenseNet169</a></td>
#         <td>Dense CNN</td>
#         <td>ImageNet</td>
#         <td>57</td>
#         <td>76.2%</td>
#         <td>93.2%</td>
#         <td>14.3M</td>
#         <td>338</td>
#         <td>Computer Vision</td>
#         <td>96.4</td>
#         <td>6.3</td>
#       </tr>
#       <tr>
#         <td>16</td>
#         <td><a href="https://keras.io/api/applications/densenet/#densenet201-function">DenseNet201</a></td>
#         <td>Dense CNN</td>
#         <td>ImageNet</td>
#         <td>80</td>
#         <td>77.3%</td>
#         <td>93.6%</td>
#         <td>20.2M</td>
#         <td>402</td>
#         <td>Computer Vision</td>
#         <td>127.2</td>
#         <td>6.7</td>
#       </tr>
#       <tr>
#         <td>17</td>
#         <td><a href="https://keras.io/api/applications/nasnet/#nasnetmobile-function">NASNetMobile</a></td>
#         <td>Neural Architecture Search CNN</td>
#         <td>ImageNet</td>
#         <td>23</td>
#         <td>74.4%</td>
#         <td>91.9%</td>
#         <td>5.3M</td>
#         <td>389</td>
#         <td>Computer Vision (Edge Devices)</td>
#         <td>27.0</td>
#         <td>6.7</td>
#       </tr>
#       <tr>
#         <td>18</td>
#         <td><a href="https://keras.io/api/applications/nasnet/#nasnetlarge-function">NASNetLarge</a></td>
#         <td>Neural Architecture Search CNN</td>
#         <td>ImageNet</td>
#         <td>343</td>
#         <td>82.5%</td>
#         <td>96.0%</td>
#         <td>88.9M</td>
#         <td>533</td>
#         <td>Computer Vision</td>
#         <td>344.5</td>
#         <td>20.0</td>
#       </tr>
#       <tr>
#         <td>19</td>
#         <td><a href="https://keras.io/api/applications/efficientnet/#efficientnetb0-function">EfficientNetB0</a></td>
#         <td>Efficient CNN</td>
#         <td>ImageNet</td>
#         <td>29</td>
#         <td>77.1%</td>
#         <td>93.3%</td>
#         <td>5.3M</td>
#         <td>132</td>
#         <td>Computer Vision</td>
#         <td>46.0</td>
#         <td>4.9</td>
#       </tr>
#       <tr>
#         <td>20</td>
#         <td><a href="https://keras.io/api/applications/efficientnet/#efficientnetb1-function">EfficientNetB1</a></td>
#         <td>Efficient CNN</td>
#         <td>ImageNet</td>
#         <td>31</td>
#         <td>79.1%</td>
#         <td>94.4%</td>
#         <td>7.9M</td>
#         <td>186</td>
#         <td>Computer Vision</td>
#         <td>60.2</td>
#         <td>5.6</td>
#       </tr>
#       <tr>
#         <td>21</td>
#         <td><a href="https://keras.io/api/applications/efficientnet/#efficientnetb2-function">EfficientNetB2</a></td>
#         <td>Efficient CNN</td>
#         <td>ImageNet</td>
#         <td>36</td>
#         <td>80.1%</td>
#         <td>94.9%</td>
#         <td>9.2M</td>
#         <td>186</td>
#         <td>Computer Vision</td>
#         <td>80.8</td>
#         <td>6.5</td>
#       </tr>
#       <tr>
#         <td>22</td>
#         <td><a href="https://keras.io/api/applications/efficientnet/#efficientnetb3-function">EfficientNetB3</a></td>
#         <td>Efficient CNN</td>
#         <td>ImageNet</td>
#         <td>48</td>
#         <td>81.6%</td>
#         <td>95.7%</td>
#         <td>12.3M</td>
#         <td>210</td>
#         <td>Computer Vision</td>
#         <td>140.0</td>
#         <td>8.8</td>
#       </tr>
#       <tr>
#         <td>23</td>
#         <td><a href="https://keras.io/api/applications/efficientnet/#efficientnetb4-function">EfficientNetB4</a></td>
#         <td>Efficient CNN</td>
#         <td>ImageNet</td>
#         <td>75</td>
#         <td>82.9%</td>
#         <td>96.4%</td>
#         <td>19.5M</td>
#         <td>258</td>
#         <td>Computer Vision</td>
#         <td>308.3</td>
#         <td>15.1</td>
#       </tr>
#       <tr>
#         <td>24</td>
#         <td><a href="https://keras.io/api/applications/efficientnet/#efficientnetb5-function">EfficientNetB5</a></td>
#         <td>Efficient CNN</td>
#         <td>ImageNet</td>
#         <td>118</td>
#         <td>83.6%</td>
#         <td>96.7%</td>
#         <td>30.6M</td>
#         <td>312</td>
#         <td>Computer Vision</td>
#         <td>579.2</td>
#         <td>25.3</td>
#       </tr>
#       <tr>
#         <td>25</td>
#         <td><a href="https://keras.io/api/applications/efficientnet/#efficientnetb6-function">EfficientNetB6</a></td>
#         <td>Efficient CNN</td>
#         <td>ImageNet</td>
#         <td>166</td>
#         <td>84.0%</td>
#         <td>96.8%</td>
#         <td>43.3M</td>
#         <td>360</td>
#         <td>Computer Vision</td>
#         <td>958.1</td>
#         <td>40.4</td>
#       </tr>
#       <tr>
#         <td>26</td>
#         <td><a href="https://keras.io/api/applications/efficientnet/#efficientnetb7-function">EfficientNetB7</a></td>
#         <td>Efficient CNN</td>
#         <td>ImageNet</td>
#         <td>256</td>
#         <td>84.3%</td>
#         <td>97.0%</td>
#         <td>66.7M</td>
#         <td>438</td>
#         <td>Computer Vision</td>
#         <td>1578.9</td>
#         <td>61.6</td>
#       </tr>
#        <tr>
#         <td>27</td>
#         <td><a href="https://keras.io/api/applications/efficientnet_v2/#efficientnetv2b0-function">EfficientNetV2B0</a></td>
#         <td>Efficient CNN</td>
#         <td>ImageNet</td>
#         <td>29</td>
#         <td>78.7%</td>
#         <td>94.3%</td>
#         <td>7.2M</td>
#         <td>-</td>
#         <td>Computer Vision</td>
#         <td>-</td>
#         <td>-</td>
#       </tr>
#       <tr>
#         <td>28</td>
#         <td><a href="https://keras.io/api/applications/efficientnet_v2/#efficientnetv2b1-function">EfficientNetV2B1</a></td>
#         <td>Efficient CNN</td>
#         <td>ImageNet</td>
#         <td>34</td>
#         <td>79.8%</td>
#         <td>95.0%</td>
#         <td>8.2M</td>
#         <td>-</td>
#         <td>Computer Vision</td>
#         <td>-</td>
#         <td>-</td>
#       </tr>
#       <tr>
#         <td>29</td>
#         <td><a href="https://keras.io/api/applications/efficientnet_v2/#efficientnetv2b2-function">EfficientNetV2B2</a></td>
#         <td>Efficient CNN</td>
#         <td>ImageNet</td>
#         <td>42</td>
#         <td>80.5%</td>
#         <td>95.1%</td>
#         <td>10.2M</td>
#         <td>-</td>
#         <td>Computer Vision</td>
#         <td>-</td>
#         <td>-</td>
#       </tr>
#       <tr>
#         <td>30</td>
#         <td><a href="https://keras.io/api/applications/efficientnet_v2/#efficientnetv2b3-function">EfficientNetV2B3</a></td>
#         <td>Efficient CNN</td>
#         <td>ImageNet</td>
#         <td>59</td>
#         <td>82.0%</td>
#         <td>95.8%</td>
#         <td>14.5M</td>
#         <td>-</td>
#         <td>Computer Vision</td>
#         <td>-</td>
#         <td>-</td>
#       </tr>
#       <tr>
#         <td>31</td>
#         <td><a href="https://keras.io/api/applications/efficientnet_v2/#efficientnetv2s-function">EfficientNetV2S</a></td>
#         <td>Efficient CNN</td>
#         <td>ImageNet</td>
#         <td>88</td>
#         <td>83.9%</td>
#         <td>96.7%</td>
#         <td>21.6M</td>
#         <td>-</td>
#         <td>Computer Vision</td>
#         <td>-</td>
#         <td>-</td>
#       </tr>
#       <tr>
#         <td>32</td>
#         <td><a href="https://keras.io/api/applications/efficientnet_v2/#efficientnetv2m-function">EfficientNetV2M</a></td>
#         <td>Efficient CNN</td>
#         <td>ImageNet</td>
#         <td>220</td>
#         <td>85.3%</td>
#         <td>97.4%</td>
#         <td>54.4M</td>
#         <td>-</td>
#         <td>Computer Vision</td>
#         <td>-</td>
#         <td>-</td>
#       </tr>
#       <tr>
#         <td>33</td>
#         <td><a href="https://keras.io/api/applications/efficientnet_v2/#efficientnetv2l-function">EfficientNetV2L</a></td>
#         <td>Efficient CNN</td>
#         <td>ImageNet</td>
#         <td>479</td>
#         <td>85.7%</td>
#         <td>97.5%</td>
#         <td>119.0M</td>
#         <td>-</td>
#         <td>Computer Vision</td>
#         <td>-</td>
#         <td>-</td>
#       </tr>
#       <tr>
#         <td>34</td>
#         <td><a href="https://keras.io/api/applications/convnext/#convnexttiny-function">ConvNeXtTiny</a></td>
#         <td>Convolutional Neural Network (CNN)</td>
#         <td>ImageNet</td>
#         <td>109.42</td>
#         <td>81.3%</td>
#         <td>-</td>
#         <td>28.6M</td>
#         <td>-</td>
#         <td>Computer Vision</td>
#         <td>-</td>
#         <td>-</td>
#       </tr>
#       <tr>
#         <td>35</td>
#         <td><a href="https://keras.io/api/applications/convnext/#convnextsmall-function">ConvNeXtSmall</a></td>
#         <td>Convolutional Neural Network (CNN)</td>
#         <td>ImageNet</td>
#         <td>192.29</td>
#         <td>82.3%</td>
#         <td>-</td>
#         <td>50.2M</td>
#         <td>-</td>
#         <td>Computer Vision</td>
#         <td>-</td>
#         <td>-</td>
#       </tr>
#        <tr>
#         <td>36</td>
#         <td><a href="https://keras.io/api/applications/convnext/#convnextbase-function">ConvNeXtBase</a></td>
#         <td>Convolutional Neural Network (CNN)</td>
#         <td>ImageNet</td>
#         <td>338.58</td>
#         <td>85.3%</td>
#         <td>-</td>
#         <td>88.5M</td>
#         <td>-</td>
#         <td>Computer Vision</td>
#         <td>-</td>
#         <td>-</td>
#       </tr>
#       <tr>
#         <td>37</td>
#         <td><a href="https://keras.io/api/applications/convnext/#convnextlarge-function">ConvNeXtLarge</a></td>
#         <td>Convolutional Neural Network (CNN)</td>
#         <td>ImageNet</td>
#         <td>755.07</td>
#         <td>86.3%</td>
#         <td>-</td>
#         <td>197.7M</td>
#         <td>-</td>
#         <td>Computer Vision</td>
#         <td>-</td>
#         <td>-</td>
#       </tr>
#         <tr>
#         <td>38</td>
#         <td><a href="https://keras.io/api/applications/convnext/#convnextxlarge-function">ConvNeXtXLarge</a></td>
#         <td>Convolutional Neural Network (CNN)</td>
#         <td>ImageNet</td>
#         <td>1310</td>
#         <td>86.7%</td>
#         <td>-</td>
#         <td>350.1M</td>
#         <td>-</td>
#         <td>Computer Vision</td>
#         <td>-</td>
#         <td>-</td>
#       </tr>
#     </tbody>
#   </table>
# <p>
# The top-1 and top-5 accuracy refers to the model's performance on the ImageNet validation dataset.
#
# Depth refers to the topological depth of the network. This includes activation layers, batch normalization layers etc. <br> Depth counts the number of layers with parameters.
#
# Time per inference step is the average of 30 batches and 10 repetitions.
# - CPU: AMD EPYC Processor (with IBPB) (92 core)
# - RAM: 1.7T
# - GPU: Tesla A100
# - Batch size: 32
#   <!-- Footer -->
#   <p style="text-align:center; font-size:12px; color:#666;">Data sourced from research papers and AI model documentation.</p>
#
# </div>
#
# </body>
# </html>

# %% [markdown]
# ### Image Classification using a pretrained model ResNet50

# %%
import keras
from keras.applications.resnet50 import ResNet50
from keras.applications.resnet50 import preprocess_input, decode_predictions
import numpy as np
import cv2

# %% [markdown]
#  ResNet50 is a specific architecture of a convolutional neural network (CNN) that is 50 layers deep. <br>
#
#  Think of it like a very sophisticated image recognition brain that has already been trained on millions of images.<br>
#
#  The weights='imagenet' parameter tells the model to load pre-trained weights from the ImageNet dataset, which contains over 1 million images across 1000 different categories.

# %%
model = ResNet50(weights='imagenet')

# %%
import matplotlib.pyplot as plt
import skimage.io as io

img = io.imread("https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQqfm1befikA9HzDD-AjN3mHZHpLspayGBYjw&s")
plt.imshow(img)
plt.axis('off')
plt.show()

# %%
img2 = cv2.resize(img, (224,224)) # resizing the image to 224x224
img2 = np.expand_dims(img2, axis=0) # coverting into batches by adding a batch dimension

# %%
print(img2.shape)
# Out:
# (1, 224, 224, 3)

# %% [markdown]
# `preprocess_input` is a function that prepares images in the correct format before feeding them into the ResNet50 model. Here's what it does:
#
# - Converts the images to the BGR color format
#
# - Scales pixel values appropriately
#
# - Performs zero-centering of the data using the mean pixel values from the ImageNet dataset

# %%
img2 = preprocess_input(img2)

# %%
preds = model.predict(img2)

# decode the results into a list of tuples (class, description, probability)
# (one such list for each sample in the batch)
# Out:
# 2025-03-07 21:15:28.362243: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:432] Loaded cuDNN version 8907
# 2025-03-07 21:15:33.457515: W tensorflow/tsl/framework/bfc_allocator.cc:296] Allocator (GPU_0_bfc) ran out of memory trying to allocate 1.08GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 1/1 [==============================] - 9s 9s/step

# %% [markdown]
# `decode_predictions` decode the predictions of imagenet model.

# %%
print('Predicted:', decode_predictions(preds, top=5)[0])
# Out:
# Predicted: [('n02504013', 'Indian_elephant', 0.803759), ('n01871265', 'tusker', 0.1800922), ('n02504458', 'African_elephant', 0.01614489), ('n02100583', 'vizsla', 1.0047235e-06), ('n02408429', 'water_buffalo', 4.585055e-07)]

# %% [markdown]
# ## 4. How CNN see?
#
# <img src = "https://storage.googleapis.com/lds-media/images/cnn-architecture.width-1200.jpg"><br>A CNN is built around an architecture similar to this graphic representation</img>

# %% [markdown]
# Deep learning networks often work like a "black box." They can make good predictions, but it's hard to understand why they made a particular prediction.
#
# However, with convolutional neural networks (CNNs), which are used for images, we have a little more insight. CNNs are built to understand images in a way that preserves the relationships between parts of the image e.g., spatial relationships. (like how edges and textures are arranged).
#
# We can actually look at parts of the CNN to see what it has learned. We can visualize the "filters" and see what kind of features the CNN is designed to find (like edges, colors, or textures). Also, when we give the CNN an image, we can look at the "activation maps" (think of them as notes the CNN takes) to see exactly what features the CNN detected in that specific image.
#
# We need a model to visualize.
# Instead of fitting a model from scratch, we are using a pre-trained image classification model VGG16.

# %%
import tensorflow as tf
from keras.applications.vgg16 import VGG16, preprocess_input

model = VGG16()
# Out:
# 2025-03-10 19:41:04.538379: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-03-10 19:41:04.647261: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE4.1 SSE4.2 AVX AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-03-10 19:41:09.749954: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 1736 MB memory:  -> device: 0, name: NVIDIA GeForce MX230, pci bus id: 0000:01:00.0, compute capability: 6.1

# %%
print(model.summary())
# Out:
# Model: "vgg16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  input_1 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 224, 224, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 224, 224, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 112, 112, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 112, 112, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 112, 112, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 56, 56, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 56, 56, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 28, 28, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 28, 28, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 28, 28, 512)       2359808
#
# ...

# %% [markdown]
# The model summary printed summarizes the output shape of each layer, e.g. the shape of the resulting feature maps. It does not give any idea of the shape of the filters (weights) in the network, only the total number of weights per layer.
#
# We can access all of the layers of the model via the model.layers property.

# %%
# summarize filter shapes
for layer in model.layers:
	# check for convolutional layer
    if 'conv' not in layer.name:
        continue
# get filter weights
    filters, biases = layer.get_weights()
    print(layer.name, filters.shape)
# Out:
# block1_conv1 (3, 3, 3, 64)
# block1_conv2 (3, 3, 64, 64)
# block2_conv1 (3, 3, 64, 128)
# block2_conv2 (3, 3, 128, 128)
# block3_conv1 (3, 3, 128, 256)
# block3_conv2 (3, 3, 256, 256)
# block3_conv3 (3, 3, 256, 256)
# block4_conv1 (3, 3, 256, 512)
# block4_conv2 (3, 3, 512, 512)
# block4_conv3 (3, 3, 512, 512)
# block5_conv1 (3, 3, 512, 512)
# block5_conv2 (3, 3, 512, 512)
# block5_conv3 (3, 3, 512, 512)

# %% [markdown]
# ### 4.1 Visualizing Filters
# We can see that all convolutional layers use 3×3 filters, which are small and perhaps easy to interpret.
#
# An architectural concern with a convolutional neural network is that the depth of a filter must match the depth of the input for the filter (e.g. the number of channels).|
#
# First convolution layer has 64 filters, with 3x3 size for each channel of Red, Green and Blue. <br>
# Visualising filters of first convolution layer..

# %% [markdown]
# <img src="https://lh3.googleusercontent.com/d/19YlIzWQXV_KYcTTAa7qG6S7P47c4yMRt"><br>a filter of (3x3x3x64)</img>

# %%
filters, biases = model.layers[1].get_weights()
print("1st Conv Layer:", filters.shape)
# Out:
# 1st Conv Layer: (3, 3, 3, 64)

# %%
# visualising 8 out of 64 filters of the first convolutional layer

import matplotlib.pyplot as plt
f_max, f_min = filters.max(), filters.min()

# applying min - max normalization to scale values between 0-1
filter = (filters - f_min) / (f_max - f_min)
plt.figure(1, figsize=(8, 8))
n_filters, ix = 8, 1
for i in range(n_filters):
    # get the filter
    f = filter[:,:,:,i]

    # plot each channel separately
    for j in range(filters.shape[2]):
        # Subplots
        ax = plt.subplot(n_filters, filters.shape[2], ix)
        ax.set_xticks([])
        ax.set_yticks([])
        # plot filter channel
        plt.imshow(f[:,:,j], cmap='gray')
        ix+=1

plt.show()

# %% [markdown]
# ### 4.2 Visualizing Feature maps
# The activation maps, called feature maps, capture the result of applying the filters to input, such as the input image or another feature map.
#
# The idea of visualizing a feature map for a specific input image would be to understand what features of the input are detected or preserved in the feature maps. The expectation would be that the feature maps close to the input detect small or fine-grained detail, whereas feature maps close to the output of the model capture more general features.
#
# In order to explore the visualization of feature maps, we need input for the VGG16 model that can be used to create activations.
#
# We will use a simple photograph.

# %%
import skimage.io as io
import cv2
import matplotlib.pyplot as plt
import numpy as np

# %%
img = io.imread("https://six5six.in/cdn/shop/files/INDIA-JerseyLarge_1024x.jpg?v=1697440965")
plt.imshow(img); plt.xticks([]); plt.yticks([]); plt.show()

# %% [markdown]
# Enumerating all convolution layers in the model and print the output size or feature map size for each convolutional layer as well as the layer index in the model.

# %%
# understanding the input layer shape and output shapes of each convolution layer
for i in range(len(model.layers)):
    layer = model.layers[i]
    if ('conv' in layer.name) or ('input' in layer.name):
        print(f"{i}.", layer.name, layer.output.shape)
# Out:
# 0. input_1 (None, 224, 224, 3)
# 1. block1_conv1 (None, 224, 224, 64)
# 2. block1_conv2 (None, 224, 224, 64)
# 4. block2_conv1 (None, 112, 112, 128)
# 5. block2_conv2 (None, 112, 112, 128)
# 7. block3_conv1 (None, 56, 56, 256)
# 8. block3_conv2 (None, 56, 56, 256)
# 9. block3_conv3 (None, 56, 56, 256)
# 11. block4_conv1 (None, 28, 28, 512)
# 12. block4_conv2 (None, 28, 28, 512)
# 13. block4_conv3 (None, 28, 28, 512)
# 15. block5_conv1 (None, 14, 14, 512)
# 16. block5_conv2 (None, 14, 14, 512)
# 17. block5_conv3 (None, 14, 14, 512)

# %% [markdown]
# we need to load the bird image with the size expected by the model, in this case, 224×224, after  seeiing the input

# %%
# resizing image
img = cv2.resize(img, (224, 224))
img = img.reshape((1,)+ img.shape) # converting into batch of 1 image
img = preprocess_input(img) # preprocessing input as per VGG16
print(img.shape)
# Out:
# (1, 224, 224, 3)

# %%
# this is how a preprocessed image looked like
plt.imshow(img.squeeze()); plt.xticks([]); plt.yticks([]); plt.show()

# %%
# redefine model to output right after the first hidden layer
from keras.models import Model
model_redf = Model(inputs=model.inputs, outputs=model.layers[1].output)

# %%
model_redf.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  input_1 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 224, 224, 64)      1792
#
# ...
# Total params: 1792 (7.00 KB)
# Trainable params: 1792 (7.00 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
feature_maps1 = model_redf.predict(img)
# Out:
# 1/1 [==============================] - 0s 67ms/step

# %%
feature_maps1.shape
# Out:
# (1, 224, 224, 64)

# %%
# plotting all 64 features into 8x8 squares
def plot_feature_maps(feature_maps, figsize=(12,12)):
    import matplotlib.pyplot as plt
    sq = 8
    ix = 1
    plt.figure(figsize=figsize)
    for _ in range(sq):
        for _ in range(sq):
            ax = plt.subplot(sq, sq, ix)
            ax.set_xticks([])
            ax.set_yticks([])
            plt.imshow(feature_maps[:, :, :, ix-1].squeeze(), cmap='gray')
            ix += 1
    plt.show()

plot_feature_maps(feature_maps1)

# %% [markdown]
# This is an interesting result and generally matches our expectation. We could update the example to plot the feature maps from the output of other specific convolutional layers.
#
# There are five main blocks in the image (e.g. `block1`, `block2`, etc.) that end in a pooling layer. The layer indexes of the last convolutional layer in each block are `[2, 5, 9, 13, 17]`.
#
# We can define a new model that has multiple outputs, one feature map output for each of the last convolutional layer in each block before pooling.

# %%
# redefine model to output right after the first hidden layer of fully connected layer

ixs = [2, 5, 9, 13, 17]
outputs = [model.layers[i].output for i in ixs]
model_redf2 = Model(inputs=model.inputs, outputs=outputs)
model_redf2.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  input_1 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 224, 224, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 224, 224, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 112, 112, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 112, 112, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 112, 112, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 56, 56, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 56, 56, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 28, 28, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 28, 28, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 28, 28, 512)       2359808
#
# ...

# %% [markdown]
# Making a prediction with this new model will result in a list of feature maps.
#
# Also, we know that the number of feature maps (e.g. depth or number of channels) in deeper layers is much more than $64$, such as $256$ or $512$. We can cap the number of feature maps visualized at $64$ for consistency.

# %%
feature_maps2 = model_redf2.predict(img)

# %%
for fmap in feature_maps2:
    plot_feature_maps(fmap)
    print("-"*100)
# Out:
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------

# %%
from keras.applications.vgg16 import decode_predictions
print("Predictions: ",decode_predictions(model.predict(img), top=3))
# Out:
# 1/1 [==============================] - 0s 40ms/step
# Predictions:  [[('n03595614', 'jersey', 0.84104264), ('n03617480', 'kimono', 0.135943), ('n03877472', 'pajama', 0.018117039)]]

# %% [markdown]
# This behavior is expected due to how convolutional neural networks (CNNs) process images layer by layer.
#
# #### Why is the first image (early layers) brighter?
# - **Low-Level Features**: The initial convolutional layers of VGG16 detect simple patterns like edges, textures, and corners.
#
# - **Higher Activation Values**: Since these patterns are present across the image, many neurons in the feature maps are activated, resulting in bright, high-contrast outputs.
#
# #### Why is the second image (deeper layers) darker?
# - **High-Level Features**: As we move deeper into the network, the layers capture more complex and abstract features like object parts and shapes.
#
# - **Sparse Activations**: Only specific regions (like eyes, nose, mouth) remain important for classification, while most neurons suppress irrelevant background information.
#
# - **ReLU & Pooling Effects**: ReLU activation zeros out many values, and max pooling keeps only the strongest signals, leading to a sparsity effect—darker visualizations.
#
# In short, early layers highlight broad patterns across the image, while later layers focus only on the most discriminative features, making the activations sparser and darker.

# %% [markdown]
# ## 5. Transfer Learning
# It is a research problem in machine learning that focuses on storing knowledge gained while solving one problem and applying it to a different but related problem.
#
# It is a machine learning technique where a pre-trained model (trained on a large dataset like ImageNet) is reused for a new but related task. Instead of training a model from scratch, we take a model that has already learned useful features and fine-tune it for our specific dataset.
#
# In the context of deep learning, transfer learning typically involves:
#
# - Taking a pre-trained model (e.g., VGG16, ResNet, or BERT) that was trained on a large dataset (e.g., ImageNet for images).
#
# - Fine-tuning or adapting the model to a new, often smaller, dataset or task.

# %% [markdown]
# <img src='https://cdn.thenewstack.io/media/2020/11/3f240627-screen-shot-2020-11-18-at-1.33.48-pm-1024x616.png'><br>Transfer learning</img>

# %% [markdown]
# ### 5.1 Why Do We Need Transfer Learning?
# 1. **Saves Time and Computational Resources** :
#
#     - Training deep learning models from scratch requires significant computational power and time, especially for large datasets.
#
#     - Transfer learning allows you to start with a pre-trained model, which has already learned useful features, reducing the training time and resource requirements.
#
# 2. **Works Well with Small Datasets** :
#
#     - Deep learning models typically require large amounts of labeled data to perform well. However, in many domains (e.g., medical imaging, satellite imagery), labeled data is scarce or expensive to obtain.
#
#     - Transfer learning enables you to use a pre-trained model that has already learned general features from a large dataset (e.g., ImageNet) and fine-tune it on a smaller dataset for a specific task.
#
# 3. **Improves Performance** :
#
#     - Pre-trained models have already learned useful features (e.g., edges, textures, shapes for images or word embeddings for text) from large datasets.
#
#     - By leveraging these features, transfer learning often leads to better performance on the target task compared to training a model from scratch, especially when the target dataset is small.
#
# 4. **Avoids Overfitting** :
#
#     - When training on small datasets, models are prone to overfitting (memorizing the training data instead of generalizing).
#
#     - Transfer learning helps mitigate this by starting with a model that has already learned general patterns, reducing the risk of overfitting.
#
# 5. **Cross domain adaption** :
#
#     - Transfer learning allows knowledge to be transferred across different but related domains. For example:

# %% [markdown]
# ### 5.2 **Real world Example - DeepFace**
# **DeepFace**, developed by **Facebook (now Meta)**, is a **real-world example of transfer learning** in action. It is a deep learning-based facial recognition system used for tasks like tagging friends in photos, detecting unauthorized use of profile pictures, and enhancing security through facial recognition login.
#
# #### How DeepFace Uses Transfer Learning
#
# ##### 1. Pre-trained Model on a Large Dataset
#    - DeepFace leverages a **pre-trained deep convolutional neural network (CNN) i.e., VGGFace**  trained on a massive dataset of labeled faces.
#    - The model is initially trained on a general-purpose face dataset (e.g., **Labeled Faces in the Wild (LFW)** or **Facebook's internal dataset**) to learn **general facial features** such as edges, textures, and facial structures.
#
# ##### 2. Feature Extraction
#    - The pre-trained model learns to extract **high-level features** from faces, such as:
#      - Distance between eyes.
#      - Shape of the nose.
#      - Jawline structure.
#    - These features are **generic** and can be applied to any face recognition task.
#
# ##### 3. Fine-Tuning for Specific Tasks
#    - DeepFace fine-tunes the pre-trained model on **Facebook's specific dataset** of user-uploaded photos.
#    - During fine-tuning:
#      - The model adapts to the specific characteristics of Facebook's data (e.g., lighting conditions, angles, and resolutions commonly found in user photos).
#      - The final layers of the model are adjusted to improve accuracy for Facebook's use cases (e.g., tagging friends or detecting fake accounts).
#
# ##### 4. Transfer of Knowledge
#    - The knowledge (learned features) from the pre-trained model is **transferred** to the new task of recognizing faces in Facebook's environment.
#    - This avoids the need to train a model from scratch, which would require:
#      - A massive dataset of labeled faces.
#      - Significant computational resources and time.
#
# #### Real-World Impact of DeepFace
# - **Tagging Friends:** DeepFace powers Facebook's photo tagging feature, making it easier for users to tag friends in photos.
# - **Security:** It helps detect fake accounts and unauthorized use of profile pictures.
# - **Accessibility:** DeepFace improves accessibility features, such as automatic alt-text generation for visually impaired users.
#
# #### Technical Details of DeepFace
# - **Architecture:** DeepFace uses a **9-layer deep neural network** with over **120 million parameters**.
# - **Training Data:** Initially trained on **4 million labeled faces** from Facebook's dataset.
# - **Accuracy:** Achieves **97.35% accuracy** on the Labeled Faces in the Wild (LFW) benchmark, which is close to human-level performance.

# %%
# ! pip install deepface
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.2/87.2 kB 6.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 108.6/108.6 kB 11.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.0/85.0 kB 9.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 51.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 66.1 MB/s eta 0:00:00
# ...
#   Created wheel for fire: filename=fire-0.7.0-py3-none-any.whl size=114249 sha256=fe4ceffa6f81311dd16402821177ae9590e4d850aca4f30efebf196fb06aca49
#   Stored in directory: /root/.cache/pip/wheels/46/54/24/1624fd5b8674eb1188623f7e8e17cdf7c0f6c24b609dfb8a89
# Successfully built fire
# ...

# %%
import tensorflow as tf
from deepface import DeepFace

## Force TensorFlow to use CPU in case GPU not able to allocate memory
# tf.config.set_visible_devices([], 'GPU')
# Out:
# 25-03-11 22:21:21 - Directory /root/.deepface has been created
# 25-03-11 22:21:21 - Directory /root/.deepface/weights has been created

# %%
import skimage.io as io
import matplotlib.pyplot as plt

imag1 = io.imread('https://etimg.etb2bimg.com/photo/52316464.cms')
imag2 = io.imread('https://st1.bollywoodlife.com/wp-content/uploads/2023/02/Collage-Maker-08-Feb-2023-08.56-AM-1.jpg?impolicy=Medium_Widthonly&w=400&h=711')
imag3 = io.imread('https://staticimg.amarujala.com/assets/images/2023/02/07/virat-kohli-duplicates-lookalike-gaurav-arora-photos_1675781450.jpeg')
imag4 = io.imread('https://www.behindwoods.com/news-shots-slideshow/chubby-boy-to-indian-skipper-11-years-memories-and-pictures-of-virat-kohli/images/2010-kohli.jpg')
imag5 = io.imread('https://thefederal.com/h-upload/2024/01/14/426807-kohli-laughs.webp')

# %%
import cv2
imgs = [imag1, imag2, imag3, imag4, imag5]
plt.figure(figsize=(15, 4))
for i in range(len(imgs)):
    ax = plt.subplot(1,len(imgs),i+1); ax.set_xticks([]); ax.set_yticks([]);
    plt.imshow(imgs[i])
plt.show()

# %%
# Convert RGB to BGR before saving with OpenCV
imag1_bgr = cv2.cvtColor(imag1, cv2.COLOR_RGB2BGR)
imag2_bgr = cv2.cvtColor(imag2, cv2.COLOR_RGB2BGR)
imag3_bgr = cv2.cvtColor(imag3, cv2.COLOR_RGB2BGR)
imag4_bgr = cv2.cvtColor(imag4, cv2.COLOR_RGB2BGR)
imag5_bgr = cv2.cvtColor(imag5, cv2.COLOR_RGB2BGR)

# Save images correctly
cv2.imwrite('1.jpg', imag1_bgr)
cv2.imwrite('2.jpg', imag2_bgr)
cv2.imwrite('3.jpg', imag3_bgr)
cv2.imwrite('4.jpg', imag4_bgr)
cv2.imwrite('5.jpg', imag5_bgr)
# Out:
# True

# %%
# verifying 1.jpg with all other jpg
imgs = [imag1, imag2, imag3, imag4, imag5]
for i in range(2,len(imgs)+1):
    result = DeepFace.verify(img1_path='1.jpg', img2_path=f'{i}.jpg', detector_backend='retinaface', model_name='FaceNet-512D')
    print(f"{i}. {result['verified']}")
# Out:
# 2. True
# 3. False
# 4. True
# 5. True

# %% [markdown]
# - Facenet by google is pre-trained on a massive dataset of faces (e.g., Labeled Faces in the Wild (LFW) and other face datasets).
#
# - This is  highly effective for tasks like face verification, where the goal is to determine if two images belong to the same person.
#
# - DeepFace uses VGG-Face as default as a pre-trained model and fine-tunes it for specific tasks (e.g., verifying faces in user-uploaded photos). But we used Facenet here.
#
# - By leveraging the knowledge (learned features) from Facenet, DeepFace can achieve high accuracy without needing to train a model from scratch.
#
# #### How Facenet is Used in DeepFace
#
# - Face Detection: The input images are processed to detect faces using a face detection backend (e.g., OpenCV, retinaface, mtcnn, yolov8).
#
# - Feature Extraction: The detected faces are passed through the Facenet model to generate face embeddings (128-dimensional vectors representing the facial features).
#
# - Similarity Calculation: The cosine similarity metric is used to compare the face embeddings of two images. If the distance between the embeddings is below a certain threshold, the faces are considered a match.
#
# - Verification Result: The result ('verified': True or 'verified': False) is returned, along with additional details like the distance, threshold, and facial areas.
#
# #### What DeepFace.verify Does?
#
# DeepFace.verify is a complete pipeline that integrates multiple steps to perform face verification. Here's how it works:
#
# 1. **Face Detection:**
#
#     Uses a face detection backend (e.g., OpenCV, Dlib, or MTCNN) to locate faces in the input images.
#
#     **Example**: Detects the bounding box around a face in img1_path and img2_path.
#
# 2. **Face Alignment (Optional):**
#
#     Aligns the detected faces to a standard pose (e.g., frontal view) to improve accuracy.
#
#     Example: Rotates the face so that the eyes are horizontally aligned.
#
# 3. **Face Embedding Generation:**
#
#     Uses a pre-trained model (e.g., Facenet, VGG-Face) to generate face embeddings.
#
#     Example: Passes the aligned face through Facenet to generate a 128-dimensional embedding.
#
# 4. **Similarity Calculation:**
#
#     Compares the embeddings of the two faces using a similarity metric (e.g., cosine similarity, Euclidean distance).
#
#     Example: Calculates the cosine similarity between the embeddings of img1_path and img2_path.
#
# 5. **Verification:**
#
#     Compares the similarity score to a predefined threshold to determine if the faces belong to the same person.
#
#     Example: If the cosine similarity is above the threshold (e.g., 0.40 for Facenet), the faces are verified as the same person.
#
# **Que. Why Facenet Alone is Not Enough**
# - Facenet is just the embedding model. It cannot:
#   - Detect faces in an image.
#   - Align faces to a standard pose.
#   - Compare embeddings or apply a threshold for verification.
# - These additional steps are essential for a complete face verification pipeline, which is why `DeepFace.verify` is needed.

# %%
result = DeepFace.analyze("4.jpg", actions=["age", "gender", "emotion", 'race'], detector_backend='retinaface')
# Out:
# Action: race: 100%|██████████| 4/4 [00:02<00:00,  1.80it/s]

# %%
result
# Out:
# [{'age': 29,
#   'region': {'x': 131,
#    'y': 157,
#    'w': 229,
#    'h': 307,
#    'left_eye': (170, 285),
#    'right_eye': (269, 282)},
#   'face_confidence': 1.0,
#   'gender': {'Woman': 0.03701109380926937, 'Man': 99.96298551559448},
#   'dominant_gender': 'Man',
#   'emotion': {'angry': 55.331337451934814,
#    'disgust': 4.178068752514613e-11,
#    'fear': 0.004630117109627463,
#    'happy': 0.00028808703973481897,
#    'sad': 3.3382225781679153,
#    'surprise': 1.2049944375647215e-08,
#    'neutral': 41.32552742958069},
#   'dominant_emotion': 'angry',
#   'race': {'asian': 4.758529276164131,
#    'indian': 15.849303653794745,
#    'black': 5.043608623362101,
#    'white': 20.917975659249763,
#    'middle eastern': 29.242046430232907,
#    'latino hispanic': 24.188539337428768},
#   'dominant_race': 'middle eastern'}]

# %%
import pandas as pd
pd.DataFrame(result).loc[:,['age', 'dominant_gender','dominant_emotion', 'dominant_race']].T
# Out:
#                                0
# age                           29
# dominant_gender              Man
# dominant_emotion           angry
# dominant_race     middle eastern

# %% [markdown]
# **The DeepFace library supports these state-of-the-art face recognition models.**
#
# <img src='https://raw.githubusercontent.com/serengil/deepface/master/icon/model-portfolio-20240316.jpg'>The DeepFace library supports 7 state-of-the-art face recognition models.</img>

# %% [markdown]
# Experiments show that human beings achieve a 97.53% score for facial recognition on the Labeled Faces in the Wild dataset. Interestingly, VGG-Face, FaceNet, Dlib, and ArcFace have already passed that score (better-than-human-performing AI algorithms). On the other hand, OpenFace, DeepFace, and DeepID show a very close score to human performance.
#
# To use these models, they can be set as an argument in the DeepFace functions:

# %% [markdown]
# ### 5.3 How Transfer learning works
#
# We have a model train on Cat and Dog image classification, imagine we have a second dataset that shows pictures of cows and horses. Cows and horses are significantly different from cats.<br>
# Nevertheless, they are all mammals, they have four feet, and a similar shape. As a solution, we can take the layers that describe the shape of the object we want to detect, whether it is a dog, a cow, or a horse, and freeze them. Freezing means we cut them out of our predictive function $f$ put them in our predictive function $g$, and train the function $g$, without training our frozen layers:

# %% [markdown]
# <img src="https://lh3.googleusercontent.com/d/1QSfo8Xhl9rK56VIv0qCGCUTHMQzFQC2L"><br>Transfer layers from one model to another</img>

# %% [markdown]
# We can see the layers on the right side are green, which indicates that we have to train them while creating our predictive function for the source domain. On the other hand, the predictive $g$ is created using the already existing, frozen layer from the source domain. The frozen layers stay untouched during the training process.

# %% [markdown]
# ### 5.4 How Does Transfer Learning Work?
# Transfer learning is a machine learning technique where a pre-trained model (trained on a large dataset) is fine-tuned or used as a feature extractor for a new task. Instead of training a model from scratch, transfer learning leverages knowledge from a source task to improve performance on a target task.

# %% [markdown]
# <img src='https://storage.googleapis.com/lds-media/images/vgg16-architecture.width-1200.jpg'><br>The VGG16 Model has 16 Convolutional and Max Pooling layers, 3 Dense layers for the Fully-Connected layer, and an output layer of 1,000 nodes.</img>

# %% [markdown]
# #### Two Main Methods of Transfer Learning
# 1. Feature Extraction (Using Pre-trained Model as a Fixed Feature Extractor)
# 2. Fine-tuning (Retraining Some or All Layers)
#
# #### **1. Feature Extraction (Frozen Layers)**
# * A pre-trained model (like ResNet, VGG, or BERT) is used as a fixed feature extractor.
# * The lower layers of the model (which have learned generic features like edges, shapes, and textures) remain frozen.
# * Only the final layers (classifier or regressor) are replaced and trained on the new dataset.
#
# **e.g.**, We have a small dataset of X-ray images and want to classify them as normal or pneumonia. Since X-ray datasets are small, training a model from scratch is not feasible.<br>
# Instead, we use a pre-trained CNN (like VGG16) and replace its classifier. The early layers of VGG16 already detect edges & textures, which work well for X-ray images, so we don't want to retrain all the layers.

# %% [markdown]
# <img src='https://storage.googleapis.com/lds-media/images/transfer-learning-feature-extraction-approach.width-1200.jpg'>The above graphic shows the "top" portion of the model as removed. The model convolves the pre-trained output layers left behind as a 3D stack of feature maps.</img>

# %% [markdown]
# We'll pass our images through VGG16's convolutional layers to extract convolved visual features, which will output a Feature Stack of the detected visual features. From here, it's easy to flatten the 3-Dimensional feature stack into a NumPy array - ready to feed into our new fully connected layers.

# %% [markdown]
# #### **2. Fine-Tuning (Unfreezing Some or All Layers)**
#
# * Instead of keeping all layers frozen, some deeper layers are unfrozen and retrained on the new dataset.
# * This allows the model to adjust its feature extraction to the specific characteristics of the new data.
# * The first few layers remain frozen since they capture generic features (edges, textures), while deeper layers are fine-tuned.
#
# The frozen pre-trained layers will convolve visual features as usual. The non-frozen (i.e., the 'trainable') pre-trained layers will be trained on our custom dataset and update according to the Fully-Connected layer's predictions.

# %% [markdown]
# <img src = 'https://storage.googleapis.com/lds-media/images/transfer-learning-fine-tuning-approach.width-1200.jpg'><br>The final convolutional and pooling layers are unfrozen to allow training. A Fully-Connected layer is defined for training and prediction.</img>

# %% [markdown]
# **e.g.**, We are building an autonomous vehicle that detects traffic signs. The available dataset is moderate-sized (10,000+ images), and signs may have different angles/brightness than those in ImageNet.<br>
# We fine-tune the deeper layers of ResNet to adapt to new patterns. We only unfreeze the last few layers, so the model learns traffic signs while retaining general features.

# %% [markdown]
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>Transfer Learning Methods</title>
#     <style>
#     body {
#       font-family: Arial, sans-serif;
#       background-color: #f9f9f9;
#     }
#     .table-container {
#       max-width: 950px;
#       margin: auto;
#       padding: 20px;
#       background-color: white;
#       border-radius: 10px;
#       color: rgb(73, 6, 6);
#       box-shadow: 0 0 10px rgba(0, 0, 0, 0.1);
#     }
#     table {
#       width: 100%;
#       border-collapse: collapse;
#     }
#     th, td {
#       padding: 12px;
#       text-align: left;
#       border-bottom: 1px solid #ddd;
#     }
#     h4 {
#         color: rgb(219, 176, 230);
#     }
#     th {
#       background-color:rgb(96, 12, 104);
#       color: white;
#     }
#     tr:nth-child(even) {
#       background-color: #f2f2f2;
#     }
#     tr:hover {
#       background-color: #ddd;
#     }
#     .scrollable-body {
#       max-height: 300px; /* Set the height of the scrollable area */
#       overflow-y: auto; /* Enables vertical scrolling */
#     }
#     td:first-child {
#     background-color:rgba(224, 156, 241, 0.8); /* Change this to any color you like */
#     font-weight: bold;
# }
#   </style>
# </head>
# <body>
# <h4>Comparison of Transfer Learning Methods</h4>
# <div class="table-container">
# <table>
#     <tr>
#         <th>Aspect</th>
#         <th>Feature Extraction</th>
#         <th>Fine-Tuning</th>
#     </tr>
#     <tr>
#         <td>Definition</td>
#         <td>Uses pre-trained model layers as fixed feature extractors</td>
#         <td>Unfreezes some layers to refine the model for the new task</td>
#     </tr>
#     <tr>
#         <td>Training Process</td>
#         <td>Only the classifier (fully connected layers) is trained</td>
#         <td>Some of the pre-trained layers are also updated</td>
#     </tr>
#     <tr>
#         <td>Computational Cost</td>
#         <td>Lower (fewer trainable parameters)</td>
#         <td>Higher (requires backpropagation through more layers)</td>
#     </tr>
#     <tr>
#         <td>Adaptability</td>
#         <td>Good for general tasks with similar data</td>
#         <td>Better for domain-specific refinements</td>
#     </tr>
#     <tr>
#         <td>Risk of Overfitting</td>
#         <td>Lower</td>
#         <td>Higher, especially with small datasets</td>
#     </tr>
# </table>
# </div>
# </body>
# </html>

# %% [markdown]
# ### 5.5 Code practice
# #### 5.5.1 **feature extraction transfer learning(without data augmentation)**

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("salader/dogs-vs-cats")

print("Path to dataset files:", path)
# Out:
# ...
# Path to dataset files: /home/naman/.cache/kagglehub/datasets/salader/dogs-vs-cats/versions/1

# %%
import tensorflow
from tensorflow import keras
from keras import Sequential
from keras.layers import Dense,Flatten
from keras.applications.vgg16 import VGG16

# %%
# using VGG16 pretrained model
conv_base = VGG16(weights='imagenet', include_top = False, input_shape=(150,150,3))
# include_top=False: Removes the final classification layers of VGG16, Useful for transfer learning on custom datasets

# %%
conv_base.summary()
# Out:
# Model: "vgg16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  input_6 (InputLayer)        [(None, 150, 150, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 150, 150, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 150, 150, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 75, 75, 64)        0
#
#  block2_conv1 (Conv2D)       (None, 75, 75, 128)       73856
#
#  block2_conv2 (Conv2D)       (None, 75, 75, 128)       147584
#
#  block2_pool (MaxPooling2D)  (None, 37, 37, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 37, 37, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 37, 37, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 37, 37, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 18, 18, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 18, 18, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 18, 18, 512)       2359808
#
# ...

# %%
# freezing the convolutional layers
conv_base.trainable = False

# %% [markdown]
# No flatten and fully connected layer here.
#
# Creating our custom fully connected layer network

# %%
model1 = Sequential()

model1.add(conv_base)
model1.add(Flatten())
model1.add(Dense(256,activation='relu'))
model1.add(Dense(1,activation='sigmoid'))

# %%
model1.summary()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  vgg16 (Functional)          (None, 4, 4, 512)         14714688
#
#  flatten_5 (Flatten)         (None, 8192)              0
#
#  dense_10 (Dense)            (None, 256)               2097408
#
#  dense_11 (Dense)            (None, 1)                 257
#
# ...
# Total params: 16812353 (64.13 MB)
# Trainable params: 2097665 (8.00 MB)
# Non-trainable params: 14714688 (56.13 MB)
# _________________________________________________________________

# %%
# generators for feeding images in batch to model

train_ds = keras.utils.image_dataset_from_directory(
    directory = 'data/cat_n_dog/train',
    labels='inferred',
    label_mode = 'int',
    batch_size=32,
    image_size=(150,150)
)

validation_ds = keras.utils.image_dataset_from_directory(
    directory = 'data/cat_n_dog/test',
    labels='inferred',
    label_mode = 'int',
    batch_size=32,
    image_size=(150,150)
)
# Out:
# Found 20000 files belonging to 2 classes.
# Found 3568 files belonging to 2 classes.

# %%
def process(image, label):
    image = tensorflow.cast(image/255. , tensorflow.float32)
    return image, label

train_ds = train_ds.map(process)
validation_ds = validation_ds.map(process)

# %%
model1.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

history = model1.fit(train_ds, epochs = 10, validation_data = validation_ds)
# Out:
# Epoch 1/10
# 63/63 [==============================] - 59s 886ms/step - loss: 0.4462 - accuracy: 0.8056 - val_loss: 0.2943 - val_accuracy: 0.8708
# Epoch 2/10
# 63/63 [==============================] - 47s 748ms/step - loss: 0.1978 - accuracy: 0.9133 - val_loss: 0.2871 - val_accuracy: 0.8757
# Epoch 3/10
# 63/63 [==============================] - 48s 760ms/step - loss: 0.1210 - accuracy: 0.9591 - val_loss: 0.2735 - val_accuracy: 0.8911
# Epoch 4/10
# 63/63 [==============================] - 49s 775ms/step - loss: 0.0886 - accuracy: 0.9696 - val_loss: 0.3596 - val_accuracy: 0.8617
# Epoch 5/10
# 63/63 [==============================] - 49s 781ms/step - loss: 0.0655 - accuracy: 0.9831 - val_loss: 0.3389 - val_accuracy: 0.8799
# Epoch 6/10
# 63/63 [==============================] - 50s 788ms/step - loss: 0.0541 - accuracy: 0.9821 - val_loss: 0.4916 - val_accuracy: 0.8380
# Epoch 7/10
# ...

# %% [markdown]
# Lot of  overfitting here. <br>
# Our training accuracy is 1 but validation_set accuracy increased from 0.87 to 0.88 only.

# %%
import matplotlib.pyplot as plt

plt.style.use('ggplot')
# Create the figure and subplots
fig, ax = plt.subplots(1, 2, figsize=(12, 5))

# Plot for loss
ax[0].plot(history.history['loss'], label='train')
ax[0].plot(history.history['val_loss'], label='val')
ax[0].set(title='Training and Validation Loss', xlabel='Epochs', ylabel='Loss')
ax[0].legend()

# Plot for accuracy
ax[1].plot(history.history['accuracy'], label='train')
ax[1].plot(history.history['val_accuracy'], label='val')
ax[1].set(title='Training and Validation Accuracy', xlabel='Epochs', ylabel='Accuracy')
ax[1].legend()

# Display the plots
plt.tight_layout()  # Adjust layout to prevent overlap
plt.show()

# %%
import cv2
import skimage.io as io
img = io.imread("https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcR9jfp_3SK2bUyVUxdEhgrxfeaABTjii5gkiw&s")
plt.xticks([]); plt.yticks([]); plt.imshow(img);

# %%
import numpy as np
img = cv2.resize(img, (150,150)) # resizing the image to 224x224
img = np.expand_dims(img, axis=0) # coverting into batches by adding a batch dimension
img = tensorflow.cast(img/255., tensorflow.float32)

# %%
print(img.shape)
# Out:
# (1, 150, 150, 3)

# %%
model1.predict(img)
# Out:
# 1/1 [==============================] - 0s 46ms/step
# array([[0.0003492]], dtype=float32)

# %% [markdown]
# Output is $0$, i.e., Cat

# %%
# predicting dog also
img2 = io.imread("https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSZtmcKMAebCm9m1vdU5CJvbCUKMNLnaw3IRw&s")
plt.xticks([]); plt.yticks([]); plt.imshow(img2);

# %%
img2 = cv2.resize(img2, (150,150)) # resizing the image to 224x224
img2 = np.expand_dims(img2, axis=0) # coverting into batches by adding a batch dimension
img2 = tensorflow.cast(img2/255., tensorflow.float32)

# %%
model1.predict(img2)
# Out:
# 1/1 [==============================] - 0s 46ms/step
# array([[1.]], dtype=float32)

# %% [markdown]
# Output is $1$, i.e., Dog

# %% [markdown]
# #### 5.5.2 **feature extraction transfer learning(with data augmentation)**

# %% [markdown]
# __Data augmentation__ is the process of increasing the amount and diversity of data. We do not collect new data, rather we transform the already present data. Data means, image data here.
#
# **How it works**
#
# - Data augmentation makes small changes to the original data, such as cropping, rotating, Shearing, Zooming, brightness level and flipping.
# - It can be used in training, testing, or both.
# - It can help prevent overfitting, which is when a model performs well on training data but not on unseen data.
#
# **Benefits**
#
# - It can improve model optimization and generalizability.
# - It can prevent overfitting by exposing models to a wider range of scenarios.
# - It can help models perform better on low-resources.
# - It's cost-effective because it doesn't require collecting and annotating a large, diverse datase

# %% [markdown]
# <img src = 'https://ubiai.tools/wp-content/uploads/2023/11/UKwFg.jpg'><br>Image Data Augmentation</img>

# %%
model2 = Sequential()

model2.add(conv_base)
model2.add(Flatten())
model2.add(Dense(256,activation='relu'))
model2.add(Dense(1,activation='sigmoid'))

model2.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  vgg16 (Functional)          (None, 4, 4, 512)         14714688
#
#  flatten_3 (Flatten)         (None, 8192)              0
#
#  dense_6 (Dense)             (None, 256)               2097408
#
#  dense_7 (Dense)             (None, 1)                 257
#
# ...
# Total params: 16812353 (64.13 MB)
# Trainable params: 2097665 (8.00 MB)
# Non-trainable params: 14714688 (56.13 MB)
# _________________________________________________________________

# %%
# data augmentation generator
from keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img

batch_size = 32

train_data_gen = ImageDataGenerator(
    rescale=1./255,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True)

test_data_gen = ImageDataGenerator(rescale=1./255)

train_generator = train_data_gen.flow_from_directory(
    'data/cat_n_dog/train', target_size=(150, 150), batch_size=batch_size, class_mode='binary')

test_generator = test_data_gen.flow_from_directory(
    'data/cat_n_dog/test', target_size=(150, 150), batch_size=batch_size, class_mode='binary')
# Out:
# Found 20000 images belonging to 2 classes.
# Found 3568 images belonging to 2 classes.

# %%
model2.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
history2 = model2.fit(train_generator, epochs=10, validation_data=test_generator)
# Out:
# Epoch 1/10
# 625/625 [==============================] - 401s 635ms/step - loss: 0.2982 - accuracy: 0.8672 - val_loss: 0.2300 - val_accuracy: 0.9033
# Epoch 2/10
# 625/625 [==============================] - 694s 1s/step - loss: 0.2382 - accuracy: 0.8990 - val_loss: 0.2138 - val_accuracy: 0.9086
# Epoch 3/10
# 625/625 [==============================] - 464s 742ms/step - loss: 0.2209 - accuracy: 0.9040 - val_loss: 0.2064 - val_accuracy: 0.9114
# Epoch 4/10
# 625/625 [==============================] - 355s 568ms/step - loss: 0.2106 - accuracy: 0.9122 - val_loss: 0.2385 - val_accuracy: 0.8949
# Epoch 5/10
# 625/625 [==============================] - 346s 553ms/step - loss: 0.2021 - accuracy: 0.9143 - val_loss: 0.1999 - val_accuracy: 0.9128
# Epoch 6/10
# 625/625 [==============================] - 342s 546ms/step - loss: 0.1959 - accuracy: 0.9187 - val_loss: 0.1945 - val_accuracy: 0.9212
# Epoch 7/10
# ...

# %%
import matplotlib.pyplot as plt

plt.style.use('ggplot')
# Create the figure and subplots
fig, ax = plt.subplots(1, 2, figsize=(12, 5))

# Plot for loss
ax[0].plot(history2.history['loss'], label='train')
ax[0].plot(history2.history['val_loss'], label='val')
ax[0].set(title='Training and Validation Loss', xlabel='Epochs', ylabel='Loss')
ax[0].legend()

# Plot for accuracy
ax[1].plot(history2.history['accuracy'], label='train')
ax[1].plot(history2.history['val_accuracy'], label='val')
ax[1].set(title='Training and Validation Accuracy', xlabel='Epochs', ylabel='Accuracy')
ax[1].legend()

# Display the plots
plt.tight_layout()  # Adjust layout to prevent overlap
plt.show()

# %% [markdown]
# No overfitting and also good accuracy.

# %% [markdown]
# #### 5.5.3 **fine tuning transfer learning**

# %%
import tensorflow
from tensorflow import keras
from keras import Sequential
from keras.layers import Dense,Flatten
from keras.applications.vgg16 import VGG16

# %%
conv_base = VGG16(
    weights='imagenet',
    include_top = False,
    input_shape=(150,150,3)
)

# %%
conv_base.trainable = True

set_trainable = False

for layer in conv_base.layers:
    if layer.name == 'block5_conv1':
        set_trainable = True
    if set_trainable:
        layer.trainable = True
    else:
        layer.trainable = False

for layer in conv_base.layers:
    print(layer.name,"==>", layer.trainable)
# Out:
# input_5 ==> False
# block1_conv1 ==> False
# block1_conv2 ==> False
# block1_pool ==> False
# block2_conv1 ==> False
# block2_conv2 ==> False
# block2_pool ==> False
# block3_conv1 ==> False
# block3_conv2 ==> False
# block3_conv3 ==> False
# block3_pool ==> False
# block4_conv1 ==> False
# block4_conv2 ==> False
# block4_conv3 ==> False
# block4_pool ==> False
# block5_conv1 ==> True
# block5_conv2 ==> True
# block5_conv3 ==> True
# block5_pool ==> True

# %%
conv_base.summary()
# Out:
# Model: "vgg16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  input_5 (InputLayer)        [(None, 150, 150, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 150, 150, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 150, 150, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 75, 75, 64)        0
#
#  block2_conv1 (Conv2D)       (None, 75, 75, 128)       73856
#
#  block2_conv2 (Conv2D)       (None, 75, 75, 128)       147584
#
#  block2_pool (MaxPooling2D)  (None, 37, 37, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 37, 37, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 37, 37, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 37, 37, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 18, 18, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 18, 18, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 18, 18, 512)       2359808
#
# ...

# %%
model3 = Sequential()

model3.add(conv_base)
model3.add(Flatten())
model3.add(Dense(256,activation='relu'))
model3.add(Dense(1,activation='sigmoid'))

model3.summary()
# Out:
# Model: "sequential_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  vgg16 (Functional)          (None, 4, 4, 512)         14714688
#
#  flatten_7 (Flatten)         (None, 8192)              0
#
#  dense_14 (Dense)            (None, 256)               2097408
#
#  dense_15 (Dense)            (None, 1)                 257
#
# ...
# Total params: 16812353 (64.13 MB)
# Trainable params: 2097665 (8.00 MB)
# Non-trainable params: 14714688 (56.13 MB)
# _________________________________________________________________

# %%
2359808 * 3 + 2097408 + 257
# Out:
# 9177089

# %%
train_ds = keras.utils.image_dataset_from_directory(
    directory="data/cat_n_dog/train",
    labels="inferred",
    label_mode="int",
    batch_size=32,
    image_size=(150, 150),
)

validation_ds = keras.utils.image_dataset_from_directory(
    directory="data/cat_n_dog/test",
    labels="inferred",
    label_mode="int",
    batch_size=32,
    image_size=(150, 150),
)
# Out:
# Found 20000 files belonging to 2 classes.
# Found 3568 files belonging to 2 classes.

# %%
def process(image,label):
    image = tensorflow.cast(image/255. ,tensorflow.float32)
    return image,label

train_ds = train_ds.map(process)
validation_ds = validation_ds.map(process)

# %%
# Yes! When fine-tuning a pre-trained model, it's crucial to use a very low learning rate like 1e-5 when using RMSprop (or Adam, SGD, etc.).

model3.compile(loss='binary_crossentropy', optimizer=keras.optimizers.RMSprop(lr = 1e-5), metrics=['accuracy'])

# %%
history3 = model3.fit(train_ds, epochs=10, validation_data=validation_ds)
# Out:
# Epoch 1/10
# 625/625 [==============================] - 423s 670ms/step - loss: 0.3368 - accuracy: 0.8608 - val_loss: 0.2271 - val_accuracy: 0.9092
# Epoch 2/10
# 625/625 [==============================] - 471s 754ms/step - loss: 0.2146 - accuracy: 0.9089 - val_loss: 0.1922 - val_accuracy: 0.9179
# Epoch 3/10
# 625/625 [==============================] - 474s 758ms/step - loss: 0.1819 - accuracy: 0.9229 - val_loss: 0.2344 - val_accuracy: 0.9027
# Epoch 4/10
# 625/625 [==============================] - 486s 778ms/step - loss: 0.1563 - accuracy: 0.9368 - val_loss: 0.2047 - val_accuracy: 0.9095
# Epoch 5/10
# 625/625 [==============================] - 493s 788ms/step - loss: 0.1297 - accuracy: 0.9477 - val_loss: 0.2068 - val_accuracy: 0.9131
# Epoch 6/10
# 625/625 [==============================] - 487s 778ms/step - loss: 0.1086 - accuracy: 0.9554 - val_loss: 0.2567 - val_accuracy: 0.8994
# Epoch 7/10
# ...

# %%
import matplotlib.pyplot as plt

plt.style.use('ggplot')
# Create the figure and subplots
fig, ax = plt.subplots(1, 2, figsize=(12, 5))

# Plot for loss
ax[0].plot(history3.history['loss'], label='train')
ax[0].plot(history3.history['val_loss'], label='val')
ax[0].set(title='Training and Validation Loss', xlabel='Epochs', ylabel='Loss')
ax[0].legend()

# Plot for accuracy
ax[1].plot(history3.history['accuracy'], label='train')
ax[1].plot(history3.history['val_accuracy'], label='val')
ax[1].set(title='Training and Validation Accuracy', xlabel='Epochs', ylabel='Accuracy')
ax[1].legend()

# Display the plots
plt.tight_layout()  # Adjust layout to prevent overlap
plt.show()

# %% [markdown]
# Best results on Feature extraction with Data augmentation.
